# %%
# librarys

import pandas as pd

# %%
# read in the data

pd.read_csv("data/sample_data.csv")
# Out:
#     record_id  Length (cm)  BWT (mm)  CDI score  Limberg score  \
# 0           3          8.0       4.0        NaN            0.0
# 1           4          NaN       NaN        0.0            0.0
# 2           5         20.0       8.0        NaN            1.0
# 3           6          5.0       NaN        0.0            0.0
# 4           7         17.0       5.2        NaN            NaN
# 5           8          NaN       NaN        NaN            NaN
# 6           9         20.0       6.4        0.0            0.0
# 7          10          0.0       0.0        0.0            0.0
# 8          11          NaN       NaN        NaN            NaN
# 9          12          NaN       NaN        0.0            0.0
# 10         13          NaN       NaN        0.0            0.0
# 11         14          0.0       0.0        NaN            0.0
# 12         15          NaN       1.6        NaN            NaN
# 13         16          NaN       NaN        NaN            NaN
# ...
