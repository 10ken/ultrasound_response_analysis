# %%
import pandas as pd
import numpy as np

# %%
# load data
red_cap = pd.read_excel("data/lab_data.xlsx", sheet_name = "Sheet2")

red_cap
# Out:
#      marijuana_use  gender_that_is_not_listed  what_gender_identity_best  \
# 0              3.0                        NaN                        1.0
# 1              NaN                        NaN                        NaN
# 2              NaN                        NaN                        NaN
# 3              NaN                        NaN                        NaN
# 4              NaN                        NaN                        NaN
# 5              NaN                        NaN                        NaN
# 6              3.0                        NaN                        2.0
# 7              NaN                        NaN                        NaN
# 8              NaN                        NaN                        NaN
# 9              NaN                        NaN                        NaN
# 10             NaN                        NaN                        NaN
# 11             3.0                        NaN                        1.0
# ...

# %%
# we see there is hiddens rows, we want to see all rows
pd.set_option('display.max_rows', 200)
red_cap
# Out:
#      marijuana_use  gender_that_is_not_listed  what_gender_identity_best  \
# 0              3.0                        NaN                        1.0
# 1              NaN                        NaN                        NaN
# 2              NaN                        NaN                        NaN
# 3              NaN                        NaN                        NaN
# 4              NaN                        NaN                        NaN
# 5              NaN                        NaN                        NaN
# 6              3.0                        NaN                        2.0
# 7              NaN                        NaN                        NaN
# 8              NaN                        NaN                        NaN
# 9              NaN                        NaN                        NaN
# 10             NaN                        NaN                        NaN
# 11             3.0                        NaN                        1.0
# ...

# %%
# look at spaces in 4th column
red_cap.iloc[57]
# Out:
# marijuana_use                    3.0
# gender_that_is_not_listed        NaN
# what_gender_identity_best        2.0
# weight_kg                    190 lbs
# how_many_cm_tall             5' 7.5"
# pack_years                       0.0
# demographics_complete            2.0
# Name: 57, dtype: object

# %%
red_cap.dtypes
# Out:
# marijuana_use                float64
# gender_that_is_not_listed    float64
# what_gender_identity_best    float64
# weight_kg                     object
# how_many_cm_tall              object
# pack_years                   float64
# demographics_complete        float64
# dtype: object

# %% [markdown]
# # Remove spaces for all columns

# %%
# for each columns
for col in red_cap:
    
    # check if  the column has text
    if red_cap[col].dtypes == 'object':
        
        # remove any leading and trailing spaces
        red_cap[col] = red_cap[col].str.replace(' ', '')

# %%
red_cap.iloc[57, :]
# Out:
# marijuana_use                   3.0
# gender_that_is_not_listed       NaN
# what_gender_identity_best       2.0
# weight_kg                    190lbs
# how_many_cm_tall             5'7.5"
# pack_years                      0.0
# demographics_complete           2.0
# Name: 57, dtype: object

# %%
my_list = red_cap['weight_kg'].str.replace(' ', '')
my_list=my_list.unique()

# %%
my_list
# Out:
# array([nan, '190lbs', '71.6kg'], dtype=object)

# %%
np.nan == my_list[0]
# Out:
# False

# %%
# first value in list is a nan
pd.isnull(my_list[0])
# Out:
# True

# %%
# second value in list is not a nan
pd.isnull(my_list[1])
# Out:
# False

# %%
update

# %%
my_list = my_list.to_list()

for value in my_list:
    if pd.isnull(value) == False:
        idx = my_list.index(value)
        
        play_series [idx] = value

# %%
my_list.tolist().index('190lbs')
# Out:
# 1

# %%
my_list
# Out:
# array([nan, '190lbs', '71.6kg'], dtype=object)

# %%
red_cap['weight_kg']
# Out:
# 0         55.8
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6           82
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11          78
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27       36.04
# 28         NaN
# 29         NaN
# 30         NaN
# 31         NaN
# 32         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 36         NaN
# 37         NaN
# 38         NaN
# 39         NaN
# 40         105
# 41         NaN
# 42         NaN
# 43         NaN
# 44         NaN
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49         NaN
# 50         NaN
# 51       61.68
# 52         NaN
# 53         NaN
# 54         NaN
# 55         NaN
# 56         NaN
# 57     190 lbs
# ...

# %%
col='weight_kg'

global col_series
col_series = red_cap[col].copy()
col_series = col_series.tolist()
if red_cap[col].dtypes == 'object':

    # remove any leading and trailing spaces
    removed_spaces_array = red_cap[col].str.replace(' ', '')
    print(removed_spaces_array[:10])

    removed_spaces_list = removed_spaces_array.to_list()
    print(removed_spaces_list[:10])

    # update the original dataset with new values

    for val in removed_spaces_list:
        if pd.isnull(val) == False:
            idx = removed_spaces_list.index(value)
            
            print(val)
            col_series[idx]= val
            
            
col_series

# order is incorrect...
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: weight_kg, dtype: object
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# 190lbs
# 71.6kg
# ['71.6kg',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  82,
#  nan,
#  nan,
#  nan,
#  nan,
#  78,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  36.04,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  105,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  61.68,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '190 lbs',
#  nan,
#  nan,
#  115.66,
#  nan,
#  nan,
#  nan,
#  65.77,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  79.37,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '71.6kg',
#  nan,
#  nan,
#  nan,
#  63,
#  nan,
#  nan,
#  nan,
#  90,
#  nan,
#  nan,
#  nan,
#  58.96,
#  nan,
#  nan,
# ...

# %%
# for each columns
for col in red_cap:
    
    # check if  the column has text
    if red_cap[col].dtypes == 'object':
        
        # remove any leading and trailing spaces
        removed_spaces_array = red_cap[col].str.replace(' ', '')
        
        removed_spaces_list = removed_spaces_array.to_list()
        
        # update the original dataset with new values
        
        update_values(removed_spaces_list, red_cap[col])
# Out:
# /var/folders/wj/gwqv8kfj18317lgnlmf6zypw0000gn/T/ipykernel_79095/3309002339.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col_series[idx] = val
# /var/folders/wj/gwqv8kfj18317lgnlmf6zypw0000gn/T/ipykernel_79095/3309002339.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col_series[idx] = val
# /var/folders/wj/gwqv8kfj18317lgnlmf6zypw0000gn/T/ipykernel_79095/3309002339.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
def update_values(removed_spaces_list, col_series):
    
    for val in removed_spaces_list:
        if pd.isnull(val) == False:
            idx = removed_spaces_list.index(value)
            
            col_series[idx] = val
    return col_series

# %%
my_list = my_list.to_list()

for value in my_list:
    if pd.isnull(value) == False:
        idx = my_list.index(value)
        
        play_series[idx] = value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wj/gwqv8kfj18317lgnlmf6zypw0000gn/T/ipykernel_79095/1548229725.py in <cell line: 1>()
# ----> 1 my_list = my_list.to_list()
#       2
#       3 for value in my_list:
#       4     if pd.isnull(value) == False:
#       5         idx = my_list.index(value)
#
# AttributeError: 'list' object has no attribute 'to_list'

# %% [markdown]
# # Standardize Units

# %%
red_cap.dtypes
# Out:
# marijuana_use                float64
# gender_that_is_not_listed    float64
# what_gender_identity_best    float64
# weight_kg                     object
# how_many_cm_tall              object
# pack_years                   float64
# demographics_complete        float64
# dtype: object

# %% [markdown]
# ## weight_kg

# %%
red_cap.unique().tolist()
# Out:
# [nan, '190lbs', '71.6kg']

# %%
for val in red_cap['weight_kg']:
    print(val)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 190lbs
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 71.6kg
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
